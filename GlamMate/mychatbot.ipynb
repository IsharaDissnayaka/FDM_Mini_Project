# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Beauty_chatbot
# Out:
# /content/drive/MyDrive/Beauty_chatbot

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download("stopwords")
nltk.download('wordnet')

for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")

# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# <ipython-input-4-09052aad7e42>:77: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# 32 documents
# 10 classes ['discounts_promotions', 'goodbye', 'greeting', 'order_status', 'payment_methods', 'product_info', 'product_search', 'return_policy', 'shipping_info', 'thanks']
# 73 unique lemmatized words ["'m", "'s", '[', ']', 'a', 'about', 'accepted', 'any', 'appreciate', 'are', 'arrive', 'bye', 'can', 'catalog', 'day', 'discount', 'do', 'doe', 'find', 'for', 'good', 'goodbye', 'have', 'hello', 'help', 'hey', 'hi', 'how', 'i', 'is', 'later', 'long', 'looking', 'lot', 'make', 'me', 'method', 'my', 'of', 'offer', 'ongoing', 'order', 'pay', 'payment', 'payment_method', 'policy', 'product', 'product_type', 'promotion', 'return', 'see', 'sell', 'shipping', 'show', 'special', 'status', 'take', 'tell', 'thank', 'thanks', 'the', 'there', 'to', 'track', 'want', 'what', 'when', 'where', 'will', 'with', 'work', 'you', 'your']
# Training data created
# Epoch 1/200
# 7/7 [==============================] - 1s 4ms/step - loss: 2.3965 - accuracy: 0.0312
# Epoch 2/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.3928 - accuracy: 0.0938
# Epoch 3/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.3259 - accuracy: 0.1250
# Epoch 4/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2658 - accuracy: 0.1250
# Epoch 5/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2901 - accuracy: 0.1875
# Epoch 6/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2595 - accuracy: 0.1562
# Epoch 7/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2880 - accuracy: 0.0938
# Epoch 8/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.3117 - accuracy: 0.1250
# Epoch 9/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.3031 - accuracy: 0.0938
# Epoch 10/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2995 - accuracy: 0.1562
# Epoch 11/200
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2214 - accuracy: 0.0938
# Epoch 12/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2511 - accuracy: 0.1562
# Epoch 13/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2128 - accuracy: 0.1875
# Epoch 14/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.3109 - accuracy: 0.1250
# Epoch 15/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2521 - accuracy: 0.0938
# Epoch 16/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2107 - accuracy: 0.2188
# Epoch 17/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2620 - accuracy: 0.1250
# Epoch 18/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2410 - accuracy: 0.2188
# Epoch 19/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1907 - accuracy: 0.2188
# Epoch 20/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2812 - accuracy: 0.0625
# Epoch 21/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1493 - accuracy: 0.3750
# Epoch 22/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2365 - accuracy: 0.1875
# Epoch 23/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1705 - accuracy: 0.1875
# Epoch 24/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1585 - accuracy: 0.2188
# Epoch 25/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1415 - accuracy: 0.2812
# Epoch 26/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1089 - accuracy: 0.2812
# Epoch 27/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1457 - accuracy: 0.2188
# Epoch 28/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1707 - accuracy: 0.1875
# Epoch 29/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.2085 - accuracy: 0.2188
# Epoch 30/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1614 - accuracy: 0.3438
# Epoch 31/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1608 - accuracy: 0.2188
# Epoch 32/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1111 - accuracy: 0.3438
# Epoch 33/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1580 - accuracy: 0.2188
# Epoch 34/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1372 - accuracy: 0.3125
# Epoch 35/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0230 - accuracy: 0.3750
# Epoch 36/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0771 - accuracy: 0.3750
# Epoch 37/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1269 - accuracy: 0.4062
# Epoch 38/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1237 - accuracy: 0.2500
# Epoch 39/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1139 - accuracy: 0.3125
# Epoch 40/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0342 - accuracy: 0.3750
# Epoch 41/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9888 - accuracy: 0.4375
# Epoch 42/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0931 - accuracy: 0.2188
# Epoch 43/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1048 - accuracy: 0.2812
# Epoch 44/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9941 - accuracy: 0.3438
# Epoch 45/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0534 - accuracy: 0.3438
# Epoch 46/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0482 - accuracy: 0.2188
# Epoch 47/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0191 - accuracy: 0.4062
# Epoch 48/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9578 - accuracy: 0.3125
# Epoch 49/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0654 - accuracy: 0.2500
# Epoch 50/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9659 - accuracy: 0.4375
# Epoch 51/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0065 - accuracy: 0.3438
# Epoch 52/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.0492 - accuracy: 0.3125
# Epoch 53/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0443 - accuracy: 0.3750
# Epoch 54/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0279 - accuracy: 0.4062
# Epoch 55/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9108 - accuracy: 0.4688
# Epoch 56/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9809 - accuracy: 0.3750
# Epoch 57/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9080 - accuracy: 0.5625
# Epoch 58/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9653 - accuracy: 0.3125
# Epoch 59/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.8957 - accuracy: 0.5000
# Epoch 60/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0045 - accuracy: 0.3125
# Epoch 61/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9058 - accuracy: 0.4688
# Epoch 62/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8902 - accuracy: 0.4688
# Epoch 63/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.9608 - accuracy: 0.3438
# Epoch 64/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8722 - accuracy: 0.5625
# Epoch 65/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7770 - accuracy: 0.7188
# Epoch 66/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.8408 - accuracy: 0.5000
# Epoch 67/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7919 - accuracy: 0.5625
# Epoch 68/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7307 - accuracy: 0.5312
# Epoch 69/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8100 - accuracy: 0.5938
# Epoch 70/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8185 - accuracy: 0.4688
# Epoch 71/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8266 - accuracy: 0.4375
# Epoch 72/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8342 - accuracy: 0.5312
# Epoch 73/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8114 - accuracy: 0.5312
# Epoch 74/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6990 - accuracy: 0.5625
# Epoch 75/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8561 - accuracy: 0.4688
# Epoch 76/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6971 - accuracy: 0.5625
# Epoch 77/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7907 - accuracy: 0.5625
# Epoch 78/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6820 - accuracy: 0.5625
# Epoch 79/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6406 - accuracy: 0.5625
# Epoch 80/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7443 - accuracy: 0.5625
# Epoch 81/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6561 - accuracy: 0.6562
# Epoch 82/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8093 - accuracy: 0.4375
# Epoch 83/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.7345 - accuracy: 0.5312
# Epoch 84/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6091 - accuracy: 0.6250
# Epoch 85/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6707 - accuracy: 0.5625
# Epoch 86/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6020 - accuracy: 0.5625
# Epoch 87/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6590 - accuracy: 0.5625
# Epoch 88/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.6905 - accuracy: 0.5000
# Epoch 89/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.8240 - accuracy: 0.4375
# Epoch 90/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5203 - accuracy: 0.6875
# Epoch 91/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7209 - accuracy: 0.5000
# Epoch 92/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5233 - accuracy: 0.7188
# Epoch 93/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5898 - accuracy: 0.6562
# Epoch 94/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5608 - accuracy: 0.5312
# Epoch 95/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.4812 - accuracy: 0.5938
# Epoch 96/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5130 - accuracy: 0.5312
# Epoch 97/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4170 - accuracy: 0.6562
# Epoch 98/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5606 - accuracy: 0.6875
# Epoch 99/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5749 - accuracy: 0.6875
# Epoch 100/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6280 - accuracy: 0.5938
# Epoch 101/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.5725 - accuracy: 0.4375
# Epoch 102/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.4182 - accuracy: 0.6875
# Epoch 103/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.4704 - accuracy: 0.6250
# Epoch 104/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5446 - accuracy: 0.5938
# Epoch 105/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5325 - accuracy: 0.5312
# Epoch 106/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4227 - accuracy: 0.8125
# Epoch 107/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3789 - accuracy: 0.6875
# Epoch 108/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3598 - accuracy: 0.6875
# Epoch 109/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3580 - accuracy: 0.6875
# Epoch 110/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4128 - accuracy: 0.6250
# Epoch 111/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5812 - accuracy: 0.5312
# Epoch 112/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3941 - accuracy: 0.6250
# Epoch 113/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2457 - accuracy: 0.7500
# Epoch 114/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3664 - accuracy: 0.6562
# Epoch 115/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3392 - accuracy: 0.6562
# Epoch 116/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3398 - accuracy: 0.6562
# Epoch 117/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4827 - accuracy: 0.6875
# Epoch 118/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.4689 - accuracy: 0.6562
# Epoch 119/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3040 - accuracy: 0.7188
# Epoch 120/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3308 - accuracy: 0.6875
# Epoch 121/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1548 - accuracy: 0.8438
# Epoch 122/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4115 - accuracy: 0.5312
# Epoch 123/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3918 - accuracy: 0.5938
# Epoch 124/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1391 - accuracy: 0.8125
# Epoch 125/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2010 - accuracy: 0.7500
# Epoch 126/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1488 - accuracy: 0.7500
# Epoch 127/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2655 - accuracy: 0.7812
# Epoch 128/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1924 - accuracy: 0.7188
# Epoch 129/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2603 - accuracy: 0.7812
# Epoch 130/200
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0787 - accuracy: 0.7812
# Epoch 131/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2106 - accuracy: 0.6875
# Epoch 132/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0983 - accuracy: 0.8125
# Epoch 133/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1801 - accuracy: 0.7500
# Epoch 134/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1634 - accuracy: 0.7500
# Epoch 135/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1083 - accuracy: 0.6875
# Epoch 136/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1835 - accuracy: 0.7500
# Epoch 137/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1925 - accuracy: 0.6875
# Epoch 138/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2816 - accuracy: 0.5938
# Epoch 139/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0294 - accuracy: 0.7812
# Epoch 140/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0596 - accuracy: 0.7188
# Epoch 141/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1704 - accuracy: 0.7188
# Epoch 142/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1622 - accuracy: 0.6875
# Epoch 143/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2775 - accuracy: 0.5625
# Epoch 144/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9911 - accuracy: 0.8125
# Epoch 145/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8816 - accuracy: 0.9062
# Epoch 146/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1300 - accuracy: 0.6562
# Epoch 147/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0816 - accuracy: 0.7188
# Epoch 148/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1293 - accuracy: 0.6875
# Epoch 149/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.2983 - accuracy: 0.7188
# Epoch 150/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9552 - accuracy: 0.7812
# Epoch 151/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9670 - accuracy: 0.6875
# Epoch 152/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1428 - accuracy: 0.6562
# Epoch 153/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0562 - accuracy: 0.8125
# Epoch 154/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0822 - accuracy: 0.7500
# Epoch 155/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8991 - accuracy: 0.8750
# Epoch 156/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0008 - accuracy: 0.8125
# Epoch 157/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1446 - accuracy: 0.7812
# Epoch 158/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9363 - accuracy: 0.8438
# Epoch 159/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9827 - accuracy: 0.8125
# Epoch 160/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9743 - accuracy: 0.6875
# Epoch 161/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0287 - accuracy: 0.7188
# Epoch 162/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8460 - accuracy: 0.7812
# Epoch 163/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9584 - accuracy: 0.8125
# Epoch 164/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9835 - accuracy: 0.7812
# Epoch 165/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9133 - accuracy: 0.8750
# Epoch 166/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0293 - accuracy: 0.7812
# Epoch 167/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8350 - accuracy: 0.8125
# Epoch 168/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9594 - accuracy: 0.7188
# Epoch 169/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8642 - accuracy: 0.8125
# Epoch 170/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9033 - accuracy: 0.7500
# Epoch 171/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7925 - accuracy: 0.8438
# Epoch 172/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8797 - accuracy: 0.8438
# Epoch 173/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7209 - accuracy: 0.8438
# Epoch 174/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7165 - accuracy: 0.9062
# Epoch 175/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7872 - accuracy: 0.8438
# Epoch 176/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0327 - accuracy: 0.7188
# Epoch 177/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8147 - accuracy: 0.9375
# Epoch 178/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8961 - accuracy: 0.6875
# Epoch 179/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0284 - accuracy: 0.6250
# Epoch 180/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8615 - accuracy: 0.8438
# Epoch 181/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7633 - accuracy: 0.8438
# Epoch 182/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9905 - accuracy: 0.8125
# Epoch 183/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7637 - accuracy: 0.8125
# Epoch 184/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7772 - accuracy: 0.7500
# Epoch 185/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7843 - accuracy: 0.7812
# Epoch 186/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6507 - accuracy: 0.9375
# Epoch 187/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8631 - accuracy: 0.8750
# Epoch 188/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8036 - accuracy: 0.8750
# Epoch 189/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7733 - accuracy: 0.9062
# Epoch 190/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7038 - accuracy: 0.9062
# Epoch 191/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7150 - accuracy: 0.8438
# Epoch 192/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7781 - accuracy: 0.7500
# Epoch 193/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8289 - accuracy: 0.8438
# Epoch 194/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6201 - accuracy: 0.8750
# Epoch 195/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6560 - accuracy: 0.9688
# Epoch 196/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9097 - accuracy: 0.7188
# Epoch 197/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6323 - accuracy: 0.8438
# Epoch 198/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6390 - accuracy: 0.8750
# Epoch 199/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6779 - accuracy: 0.8750
# Epoch 200/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5558 - accuracy: 0.8750
# model created
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

# Initialize empty lists and variables
words = []       # Store words
classes = []     # Store intent classes
documents = []   # Store patterns and their corresponding intents
ignore_words = ['?', '!']  # Words to ignore
data_file = open('intents.json').read()  # Load JSON data from intents.json
intents = json.loads(data_file)

# Download necessary NLTK resources
import nltk
nltk.download('punkt')
nltk.download("stopwords")
nltk.download('wordnet')

# Loop through intents and patterns in the JSON data
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # Tokenize each pattern into words
        w = nltk.word_tokenize(pattern)
        words.extend(w)  # Add words to the words list
        documents.append((w, intent['tag']))  # Add patterns and corresponding intents to documents

        # Add the intent tag to the classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# Lemmatize, lowercase, and remove duplicates from the words list
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words))

# Sort intent classes
classes = sorted(list(set(classes))

# Show statistics about the dataset
print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)

# Save words and classes to pickle files for later use
pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

# Create the training data
training = []
output_empty = [0] * len(classes)

# Loop through the documents to create a bag of words for each pattern
for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]

    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# Shuffle the training data and convert to NumPy arrays
random.shuffle(training)
training = np.array(training)

# Separate patterns (X) and intents (Y)
train_x = list(training[:, 0])
train_y = list(training[:, 1])

# Create the model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile the model
sgd = SGD(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Train the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)

# Save the trained model
model.save('chatbot_model.h5', hist)

print("Model created")
